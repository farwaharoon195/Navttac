# %% [markdown]
# <a href="https://colab.research.google.com/github/farwaharoon195/Navttac/blob/main/Navttac_Tasks_11_to_14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 11

# %%
i = 10
if (i>15):
  print('10 is less than 15')
print('I am not in if')
# Out:
# I am not in if

# %%
i = 10
if (i<15):
  print('10 is less than 15')
else:
 print('I am not in if')
# Out:
# 10 is less than 15

# %%
#Task 12

# %%
i =20
if (i<15):
  print('i is smaller than 15')
  print('i am in if block')
else:
  ('i is greater than 15')
  ('i am in else block')
print('i am not in if & not in else block')
# Out:
# i am not in if & not in else block

# %%
#Task 13

# %%
i = 10
if (i==10):
  #First if statement
  if(i<15):
    print('i is smaller than 15')
  #Nested if statement
  #Will only be executed if statement above
  #it is true
  if(i<12):
    print('i is smaller than 12 too')
  else:
    print('i is greater than 15')
# Out:
# i is smaller than 15
# i is smaller than 12 too

# %%
#Task 14

# %%
i = 20
if(i==10):
  print('i is equal to 10')
elif(i==15):
  print('i is 15')
elif(i==20):
  print('i is 20')
else:
  print('i is not present')
# Out:
# i is 20
