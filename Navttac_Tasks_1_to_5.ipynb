# %% [markdown]
# <a href="https://colab.research.google.com/github/farwaharoon195/Navttac/blob/main/Navttac_Tasks_1_to_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task no 1
#Installations

# %%
#Download and install Anaconda3  Install PyTorch  Install TensorFlow 2.0  Install VSCode  Install PyCharm

# %%
#Task no 2
#Linux Commands

# %%
#Practice these commands:  pwd, cd, ls, cat, sudo, man, redirection, mkdir, rm, rmdir, cp, mv, file, reading, cat, more, less, head, alias, shutdown, restart, touch, nano, bash, sh, chmod, ps, kill, dpkg

# %%
#Task no 3
#Python
#Add two numbers

# %%
num1 = 1.5
num2 = 6.3

sum = num1 + num2

print("Sum of {0} and {1} is {2}".format (num1, num2, sum))
# Out:
# Sum of 1.5 and 6.3 is 7.8

# %%
num1 = 19
num2 = 5

sum = num1 + num2

print("Sum is :", sum)
# Out:
# Sum is : 24

# %%
#Task 3
#Python
#Add two numbers and take input from user

# %%
number1 = float(input("Enter your 1st number"))
number2 = float(input("Enter your 2nd number"))

sum = number1 + number2

print("Sum of {0} and {1} is {2}".format (number1, number2, sum))
# Out:
# Enter your 1st number30
# Enter your 2nd number50
# Sum of 30.0 and 50.0 is 80.0

# %%
number1 = input("Enter your 1st number")
number2 = input("Enter your 2nd number")

sum = float(number1) + float(number2)

print("Sum of {0} and {1} is {2}".format (number1, number2, sum))
# Out:
# Enter your 1st number20
# Enter your 2nd number30
# Sum of 20 and 30 is 50.0

# %%
#Task 5
#python
#Program to find square root

# %%
num = 16

sqrt = num*1/2

print("sqrt is :", sqrt)
# Out:
# sqrt is : 8.0

# %%
num = 8
num_sqrt = num**0.5
print("The square root of %0.3f is %0.3f"%(num,num_sqrt))
# Out:
# The square root of 8.000 is 2.828

# %%
num = float(input("Enter your fav number"))

sqrt = num*1/2

print("The square root of %0.3f is %0.3f"%(num,sqrt))
# Out:
# Enter your fav number4
# The square root of 4.000 is 2.000
