# %% [markdown]
# <a href="https://colab.research.google.com/github/farwaharoon195/Navttac/blob/main/Navttac_Task_6_to_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task no 6
#Find square root of real and complex number

# %%
import cmath

num = 1+2j

num_sqrt = cmath.sqrt(num)

print(num_sqrt)
# Out:
# (1.272019649514069+0.7861513777574233j)

# %%
import cmath

num = complex(input('Enter your number'))

num_sqrt = cmath.sqrt(num)

print('The square root of {0} is {1:0.3f}+{2:0.3f}j'.format(num,num_sqrt.real,num_sqrt.imag))
# Out:
# Enter your number1+2j
# The square root of (1+2j) is 1.272+0.786j

# %%
import cmath

num = eval(input('Enter your number'))

num_sqrt = cmath.sqrt(num)

print('The square root of {0} is {1:0.3f}+{2:0.3f}j'.format(num,num_sqrt.real,num_sqrt.imag))
# Out:
# Enter your number1+2j
# The square root of (1+2j) is 1.272+0.786j

# %%
#Task no 7
#Python program to convert temperature in celsius to fahrenheit

# %%
celsius = 37.5

fahrenheit = (celsius * 1.8 ) + 32

print('%0.1f degree celcius is equal to %0.1f fahrenheit'%(celsius,fahrenheit))
# Out:
# 37.5 degree celcius is equal to 99.5 fahrenheit

# %%
celsius = 40.9

fahrenheit = (celsius * 1.8 ) + 32

print('%0.1f degree celcius is equal to %0.1f fahrenheit'%(celsius,fahrenheit))
# Out:
# 40.9 degree celcius is equal to 105.6 fahrenheit

# %%
#Task no 8
#Python program to find the area of triangle

# %%
a = 5
b = 6
c = 7

#calculate semi parameter

s = (a+b+c)/2

#calculate the area of triangle

area = (s*(s-a)*(s-b)*(s-c))**0.5

print(area)
# Out:
# 108.0

# %%
a = float(input('Enter your number'))
b = float(input('Enter your number'))
c = float(input('Enter your number'))

s = (a+b+c)/2

area = (s*(s-a)*(s-b)*(s-c))**0.5

print('The area of triangle is %0.2f'%area )
# Out:
# Enter your number3
# Enter your number4
# Enter your number5
# The area of triangle is 6.00

# %%
#Task no 9
#Solve the quadratic equation

# %%
import cmath

a = 1
b = 2
c = 3

#Find discriminant

d = (b**2) - 4*a*c

#Find 2 solutions

sol1 = (-b-cmath.sqrt(d)/(2*a))
sol2 = (-b+cmath.sqrt(d)/(2*a))

print('the solution of {0} is {1}'.format(sol1,sol2))
# Out:
# the solution of (-2-1.4142135623730951j) is (-2+1.4142135623730951j)

# %%
#Task 10
#Input in kilometers and find miles

# %%
kilometers = float(input('Enter the number'))

#conversion factor

conv_fac = 0.621371

#Calculate miles

miles = kilometers * conv_fac

print(miles)
# Out:
# Enter the number30
# 18.64113
